-- %% [markdown]
-- DESCRIBE BASIC: Muestra las columnas, tipos de datos y comentarios de la tabla. Es útil para obtener una visión rápida de la estructura.

-- %%
describe bronze_dev.bakehouse.customer_brz

-- %% [markdown]
-- DESCRIBE EXTENDED: Proporciona información adicional sobre la tabla, incluyendo propiedades, ubicación y detalles de partición.

-- %%
describe extended bronze_dev.bakehouse.customer_brz

-- %% [markdown]
-- DESCRIBE DETAIL: Ofrece información detallada sobre la tabla Delta, como el formato, ubicación, tamaño, número de archivos y estadísticas de transacciones.

-- %%
describe detail bronze_dev.bakehouse.customer_brz

-- %% [markdown]
-- DESCRIBE HISTORY: Muestra el historial de cambios realizados en la tabla Delta, incluyendo operaciones, usuarios, fechas y versiones. Es útil para auditoría y seguimiento de modificaciones.

-- %%
describe history bronze_dev.bakehouse.customer_brz

-- %% [markdown]
-- DESCRIBE FORMATTED: Presenta la información de la tabla de forma estructurada y legible, incluyendo detalles de columnas, propiedades y particiones.

-- %%
describe formatted bronze_dev.bakehouse.customer_brz

-- %% [markdown]
-- SHOW CREATE TABLE: Muestra el comando SQL necesario para crear la tabla, incluyendo la definición de columnas, tipos de datos y propiedades. Es útil para replicar o documentar la estructura de la tabla.

-- %%
show create table bronze_dev.bakehouse.customer_brz
