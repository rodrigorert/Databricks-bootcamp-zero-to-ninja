-- %%
# --- Notebook PADRE (Orquestador) ---
import datetime

# 1. Calculamos el parámetro automáticamente (ej. la fecha de ayer)
ayer = datetime.date.today() - datetime.timedelta(days=1)
tabla_dinamica = f"ventas_{ayer}" 

# 2. Llamamos al otro notebook enviándole el parámetro
# Argumentos: "Ruta del notebook", Timeout en segundos, Diccionario de argumentos
dbutils.notebook.run("./Procesar_Ventas", 3600, {"source_table": tabla_dinamica})
