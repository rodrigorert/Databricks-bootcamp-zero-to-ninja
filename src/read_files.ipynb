# %%
#header = True para nombra de la columna
#inferSchema = True para que infiera el tipo de dato
df = spark.read.format("csv")\
        .option("header", True)\
        .option("inferSchema", True)\
        .load("/Volumes/landing_dev/data_input/data_entry/customers/")

display(df)

# %%
df = spark.read.format("csv")\
        .option("header", True)\
        .option("inferSchema", True)\
        .load("s3://lakehouse-rodrigo-reyes/landing_dev/")

display(df)

# %%
df.write.mode("overwrite").saveAsTable("bronze_dev.external_data.customers_brz")
